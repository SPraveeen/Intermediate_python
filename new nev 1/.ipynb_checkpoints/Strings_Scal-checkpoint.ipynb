# %% [markdown]
# # string is immutable

# %%
# two matrix sum

# %%
a=[[1,2,3],
  [4,5,6],
  [7,8,9]]
b=[[7,8,9],
  [4,5,6],
  [1,2,3]]

rows=len(a)
cols=len(a[0])

res=[[0 for _ in range(cols)] for _ in range(rows)]

for i in range(rows):
    for j in range(cols):
        res[i][j]=a[i][j]+b[i][j]
print(res)
# Out:
# [[8, 10, 12], [8, 10, 12], [8, 10, 12]]

# %%
r=len(a)
c=len(a[0])

re=[]
for i in range(r):
    re.append([])
    for j in range(c):
        re[i].append(a[i][j]+b[i][j])
re
# Out:
# [[8, 10, 12], [8, 10, 12], [8, 10, 12]]

# %%
#string
def sq(x):
    '''This function gives square'''
    return x*x

# %%
sq(5)
# Out:
# 25

# %%
help(sq)
# Out:
# Help on function sq in module __main__:
#
# sq(x)
#     This function gives square

# %%
'a'=='A'
# Out:
# False

# %% [markdown]
# - onnly first letter matters here/

# %%
'a'>'AZabncd'
# Out:
# True

# %%
ord('a')
# Out:
# 97

# %%
ord('A')
# Out:
# 65

# %%
ord('0')
# Out:
# 48

# %%
chr(97)
# Out:
# 'a'

# %%
chr(769)
# Out:
# '́'

# %%
chr(69)
# Out:
# 'E'

# %%
'a'=='A'
# Out:
# False

# %%
chr(1234)
# Out:
# 'Ӓ'

# %%
"pp"*2
# Out:
# 'pppp'

# %%
"pp"+"pp"
# Out:
# 'pppp'

# %%
'a-'*2*3
# Out:
# 'a-a-a-a-a-a-'

# %%
'aA'>'aB'
# Out:
# False

# %%
ord('A')
# Out:
# 65

# %%
ord('B')
# Out:
# 66

# %%
l=5
b=10
a=l*b

# %%
message='Hello World'
i=0
while i<len(message):
    if i%2==0:
        print(message[i],end='')
    i+=1
# Out:
# HloWrd

# %%
len(message)
# Out:
# 11

# %%
message[0:4:2]
# Out:
# 'Hl'

# %%
'4 5 6 6'.split()
# Out:
# ['4', '5', '6', '6']

# %%
a='a,a,a'
a.split(',')
# Out:
# ['a', 'a', 'a']

# %%
x='1 1 1 1 1'
y=x.split()

# %%
y
# Out:
# ['1', '1', '1', '1', '1']

# %%
'-'.join(y)
# Out:
# '1-1-1-1-1'

# %%
z=['this','is','a','new','title']
''.join(z)
# Out:
# 'thisisanewtitle'

# %%
' '.join(z)
# Out:
# 'this is a new title'

# %%
'this is the random'.find('is')
# Out:
# 2

# %%
'this is the random'.find(' is')
# Out:
# 4

# %% [markdown]
# - string is immutable

# %%
p='hello'
p[0]='l'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 p='hello'
# ----> 2 p[0]='l'
#
# TypeError: 'str' object does not support item assignment

# %%
a=[[1,2,3],[4,5,6],[7,8,9]]
#output = [12,15,18]
rows=3
cols=3
sTyTumm=0
for i in range(cols):
    curr=0
    for j in range(rows):
        curr+=a[j][i]
    print(curr)
# Out:
# 12
# 15
# 18

# %%
A = "aabbccbb"
B = 98 
C = 100

def solve(A,B,C):
    chr_b=chr(B)
    chr_c=chr(C)

    return A.replace(chr_b,chr_c)

# %%
solve(A,B,C)
# Out:
# 'aaddccdd'

# %%
a=set('aeiou')
print(a)
# Out:
# {'a', 'i', 'o', 'e', 'u'}
