# %% [markdown]
# - will going to cover
# -  oops (2 lectures)
# - functions(2 lectures)
# - python modules
# - exception handling
# - time complexity
# - regular expression{like template}
# - web scraping{like extracting automated}
# - git and github

# %% [markdown]
# - oops example
# - making maggi
#  - taking cooking
#  - time might slight different based on the process
#  - somepeople in kettle, microwave, stove
# - though end result is same process is different

# %% [markdown]
# - real time example
# - take student
# - student could have name,age,grade,class {attributes} {variablles}
# - action of student 'attempt test, play, bunk classes'{actions} {methods}
# - action and attributes belong to student
# - in oops we build our own datatype called {classes}
# - our class containns certain {attributes}and {methods}

# %% [markdown]
# - variables/attributes/properties
# - functions/actions/methods

# %%
class Student:
    pass

# %%
type(Student)
# Out:
# type

# %%
s1=Student()

# %% [markdown]
# - __main__ - referes current py file

# %%
type(s1)
# Out:
# __main__.Student

# %% [markdown]
# - 4 pillars of oops
#   - __Encapsulation__ {putting things altogether like creating class} {spices in kitchen kept in one container for quicker response} {for tea making sugar- tea- all in one specific location {it belongs together}}
#   - __Abstraction__ {car contains Accel, Brake, Cluc} {engine which is lot more complicated but it's hidden} {actually even don't know the knowledge of engine we can use the car}
#   - __Inheritance__ {all of them inherit lot from parents like finance/ height/ colour} {car - sedan/hatchback/suv - but having common something like passenger seat/tyre} {a way of building heirachical real world relationship in code}
#   - __Polymophism__ {4+4=8 // 'abc'+'def'=abcdef} - similar syntax different behaviour {consistent syntax/process leading to a different result depending on the input variables}
